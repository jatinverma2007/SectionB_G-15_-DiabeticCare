# %% [markdown]
# # 04 Statistical Analysis
#
# Use this notebook for deeper analysis such as correlation checks, hypothesis testing, forecasting, segmentation, or regression.

# %%
from pathlib import Path

import pandas as pd
from scipy import stats

PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().resolve().name == 'notebooks' else Path.cwd().resolve()

# %%
DATA_PATH = PROJECT_ROOT / 'data/processed/diabetic_data_clean.csv'
df = pd.read_csv(DATA_PATH)
df.head()
# Out:
# /var/folders/2_/rk291jmj0jz8nffgt1wn4wym0000gn/T/ipykernel_49845/2805522149.py:2: DtypeWarning: Columns (0: payer_code) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(DATA_PATH)
#    encounter_id  patient_nbr             race  gender  age  admission_type_id  \
# 0         12522     48330783        Caucasian  Female   85                  2
# 1         15738     63555939        Caucasian  Female   95                  3
# 2         16680     42519267        Caucasian    Male   45                  1
# 3         28236     89869032  AfricanAmerican  Female   45                  1
# 4         35754     82637451        Caucasian    Male   55                  2
#
#    discharge_disposition_id  admission_source_id  time_in_hospital payer_code  \
# 0                         1                    4                13        NaN
# 1                         3                    4                12        NaN
# 2                         1                    7                 1        NaN
# 3                         1                    7                 9        NaN
# 4                         1                    2                 3        NaN
#
#    ... total_med_changes  num_medications_active  max_glu_serum_code  \
# 0  ...                 0                       2                   0
# 1  ...                 0                       2                   0
# 2  ...                 0                       2                   0
# 3  ...                 0                       1                   0
# 4  ...                 0                       1                   0
#
#    a1cresult_code  readmitted_30day  readmitted_code  procedures_per_day  \
# 0               0                 0                0                5.38
# 1               0                 0                0                3.00
# 2               0                 0                0               51.00
# 3               0                 0                1                5.44
# 4               0                 0                1               12.33
#
#   high_med_burden polypharmacy prior_visits_total
# 0               1            0                  0
# 1               0            0                  0
# 2               0            0                  0
# 3               0            0                  0
# 4               0            0                  0
#
# [5 rows x 84 columns]

# %%
# Example placeholder for a statistical test.
# Replace with project-specific variables.
# test_stat, p_value = stats.ttest_ind(group_a, group_b, equal_var=False)
# print(test_stat, p_value)

# %%
# Record the business interpretation of each analysis directly below the code cell that produces it.
